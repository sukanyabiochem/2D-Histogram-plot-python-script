# %%
##Libraries to run the tools##
import numpy as np
import pandas as pd
import matplotlib
import matplotlib as mpl
import sys
##%matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
sns.set(style='white')
from pylab import *

# %%
df = pd.read_csv("conformation-angle-2ps-500ns.dat", delim_whitespace=True, names= ['frames', 'x','angle'])

# %%
df
# Out:
#        frames         x       angle
# 0       0.000 -2.209629  103.831686
# 1       0.002 -2.104631   95.917246
# 2       0.004 -2.279113   98.962509
# 3       0.006 -2.451480  101.622293
# 4       0.008 -2.406943   96.767769
# ...       ...       ...         ...
# 49995  99.990 -1.819982   86.902188
# 49996  99.992 -1.501598   88.218352
# 49997  99.994 -1.736488   94.006372
# 49998  99.996 -1.705719   94.356419
# 49999  99.998 -1.463362   89.879661
#
# [50000 rows x 3 columns]

# %%
###plot the ligand conformation along the x-axis in a scatter format###
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
plt.scatter(df['x'], df['angle'], c=df['frames'], cmap='viridis', vmax=0, vmin=100)
cbar=plt.colorbar()
cbar.set_label('t (ns)', fontsize=20, fontname='arial', labelpad=10)
plt.xlabel('Ligand position along X-axis', fontsize=20, labelpad=15, fontname='arial')
#plt.ylabel('Angle of the Ligand', weight='bold', fontsize=20, labelpad=15, fontname='arial')
plt.ylabel('Angle of the Ligand', fontsize=20, labelpad=15, fontname='arial')
ax.set_title('Channel 2 : Conformational Changes of the ligand', fontsize=15, fontname='arial')
plt.ylim(40, 200, 30)
plt.xlim(-25, 22, 10)
cbar.ax.tick_params(labelsize=20, direction='out', length=10, width=1.5, pad=10)
plt.tick_params(axis='both', which='major', labelsize=20, direction='in', length=10, pad=10, bottom='bool', left='bool')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.3)
plt.savefig('conformatio-500ns.png', bbox_inches='tight', dpi=600)
plt.show()
# Out:
# /var/folders/2b/bmbd5pqx3lbbl0zyb4m5h1380000gn/T/ipykernel_65527/3231365229.py:10: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(40, 200, 30)
# /var/folders/2b/bmbd5pqx3lbbl0zyb4m5h1380000gn/T/ipykernel_65527/3231365229.py:11: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(-25, 22, 10)

# %%
###not important for the plot part###
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
#cbax=fig.add_axes([0.91,0.125,0.025,0.755])
#cmap = plt.get_cmap("rainbow")
#cmap.set_under("black")
res=df.plot.scatter(x='x', y='angle', c='frames', cmap='viridis', ax=ax)
ax.set_title('Channel 2 : Conformational Changes of the ligand', fontsize=20, fontname='arial')
ax.set_xlabel('Ligand position along X-axis', weight='bold', fontsize=20, labelpad=15, fontname='arial')
ax.set_ylabel('Angle of the Ligand', weight='bold', fontsize=20, labelpad=15, fontname='arial')
#res.set_label('Contact Frequency', weight='bold', fontsize=20, fontname='arial')
#res.set_colorbar()
plt.show()
